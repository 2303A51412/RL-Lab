# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51412/RL-Lab/blob/main/lab%20assignment-2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# Part A - Machine Initialization

machines = ['A', 'B', 'C']
M = 3
N_play = 10
epsilon = 0.2

# Part B - Initialize N, R and Q

N = [0, 0, 0]
R = [0, 0, 0]
Q = [0.0, 0.0, 0.0]

total_reward = 0

# Part C, D and E
# ε-Greedy Decision, Reward and Q Update

for play in range(1, N_play + 1):
    r = random.random()
    if r < epsilon:
        selected_index = random.randint(0, M - 1)
        decision = "Exploration"
    else:
        max_q = max(Q)
        best_machines = [
            i for i in range(M)
            if Q[i] == max_q
        ]
        selected_index = random.choice(best_machines)
        decision = "Exploitation"
    selected_machine = machines[selected_index]
    print("\nPlay", play)
    print("Random number:", round(r, 4))
    print("Decision:", decision)
    print("Play with machine", selected_machine)

    # Part D - Reward Collection
    reward = float(input("Enter reward: "))

    # Part E - Update N, R and Q

    N[selected_index] += 1
    R[selected_index] += reward
    Q[selected_index] = (
        Q[selected_index]
        + (1 / N[selected_index])
        * (reward - Q[selected_index])
    )
    total_reward += reward
    print("Updated Q-value:",
          round(Q[selected_index], 4))

# Part F - Display Final Results

print("\n====================================")
print("FINAL RESULTS")
print("====================================")
print("\nMachine\tN\tR\tQ")
for i in range(M):
    print(
        machines[i],
        "\t",
        N[i],
        "\t",
        R[i],
        "\t",
        round(Q[i], 2)
    )
print("\nTotal reward after 10 plays:",
      total_reward)
# Out:
# Play 1
# Random number: 0.0132
# Decision: Exploration
# Play with machine C
# Enter reward: 65
# Updated Q-value: 65.0
#
# Play 2
# Random number: 0.0252
# Decision: Exploration
# Play with machine A
# Enter reward: 7
# Updated Q-value: 7.0
#
# Play 3
# Random number: 0.8467
# Decision: Exploitation
# Play with machine C
# Enter reward: 4
# Updated Q-value: 34.5
#
# Play 4
# Random number: 0.5986
# Decision: Exploitation
# Play with machine C
# Enter reward: 45
# Updated Q-value: 38.0
#
# Play 5
# Random number: 0.9707
# Decision: Exploitation
# Play with machine C
# Enter reward: 78
# Updated Q-value: 48.0
#
# Play 6
# Random number: 0.965
# Decision: Exploitation
# Play with machine C
# Enter reward: 23
# Updated Q-value: 43.0
#
# Play 7
# Random number: 0.6537
# Decision: Exploitation
# Play with machine C
# Enter reward: 4
# Updated Q-value: 36.5
#
# Play 8
# Random number: 0.5897
# Decision: Exploitation
# Play with machine C
# Enter reward: 56
# Updated Q-value: 39.2857
#
# Play 9
# Random number: 0.2798
# Decision: Exploitation
# Play with machine C
# Enter reward: 34
# Updated Q-value: 38.625
#
# Play 10
# Random number: 0.4776
# Decision: Exploitation
# Play with machine C
# Enter reward: 12
# Updated Q-value: 35.6667
#
# ====================================
# FINAL RESULTS
# ====================================
#
# Machine	N	R	Q
# A 	 1 	 7.0 	 7.0
# B 	 0 	 0 	 0.0
# C 	 9 	 321.0 	 35.67
#
# Total reward after 10 plays: 328.0
